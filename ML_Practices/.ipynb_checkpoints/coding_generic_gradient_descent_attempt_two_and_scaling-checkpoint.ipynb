# %%
import pandas as pd
import numpy as np
from sklearn import datasets
from sklearn import preprocessing

# %%
"""boston = datasets.load_boston()
X = boston.data
Y = boston.target"""
# Out:
# 'boston = datasets.load_boston()\nX = boston.data\nY = boston.target'

# %%
boston = np.loadtxt(r"C:\Users\HP\Coding_Ninjas_ML\DataSets\training_boston_x_y_train.csv", delimiter=",")
X = boston[:, 0:13]
Y = boston[:, 13]

# %%
from sklearn.model_selection import train_test_split

#x_train ,x_test, y_train, y_test = train_test_split(X, Y)
x_train = X
y_train = Y

scaler = preprocessing.StandardScaler()
scaler.fit(x_train)
x_train = scaler.transform(x_train)


df = pd.DataFrame(x_train)
df[13] = 1
x_train = df.values

# %%
def cost(x_data, y_data, m):
    N = len(x_data)
    total_cost = 0
    for i in range(N):
        sum_temp = 0
        for j in range(len(x_data[0])):
            sum_temp += m[j] * x_data[i][j]
        total_cost += (1/N) * ((y_data[i] - sum_temp)**2)
    return total_cost

# %%
def step_gradient(m, alpha, x_data, y_data):
    row_count = len(x_data)
    col_count = len(x_data[0])
    m_new = [0 for i in range(col_count)]
    
    for i in range(col_count):
        diff = 0
        for j in range(row_count):
            temp = 0
            for k in range(col_count):
                temp += m[k] * x_data[j][k]
            diff += (-2/row_count) * (y_data[j] - temp) * x_data[j][i]
        m_new[i] += m[i] - alpha * diff
    return m_new

# %%
def gradient_descent(x_data, y_data, num_iterations, alpha):
    m = [0 for i in range(len(x_data[0]))]
    for i in range(num_iterations):
        m = step_gradient(m, alpha, x_data, y_data)
        print(i, " Total cost : ", cost(x_data, y_data, m))
    return m

# %%
def predict(dataset, m):
    dataset = scaler.transform(dataset)
    
    df = pd.DataFrame(dataset)
    df[13] = 1
    dataset = df.values
    return np.dot(dataset, m)

# %%
def run():
    x_data = x_train.copy()
    y_data = y_train.copy()
    num_iterations = 1000
    alpha = 0.15
    m = gradient_descent(x_data, y_data, num_iterations, alpha)
    #return m
    dataset = np.loadtxt(r"C:\Users\HP\Coding_Ninjas_ML\DataSets\test_boston_x_test.csv", delimiter=",")
    prediction = predict(dataset, m)
    np.savetxt("boston_after_scaling_result.csv",prediction, delimiter=",")

# %%
run()
# Out:
# 0  Total cost :  309.9695543613457
# 1  Total cost :  168.05061211204938
# 2  Total cost :  97.7355129748779
# 3  Total cost :  62.53191135473752
# 4  Total cost :  44.68487911102569
# 5  Total cost :  35.49258832546579
# 6  Total cost :  30.65988899178741
# 7  Total cost :  28.050651459080452
# 8  Total cost :  26.593224907748287
# 9  Total cost :  25.74430826827642
# 10  Total cost :  25.22486017163791
# 11  Total cost :  24.88923290481253
# 12  Total cost :  24.659879781628213
# 13  Total cost :  24.494511193746128
# 14  Total cost :  24.369406156602818
# 15  Total cost :  24.270826527762793
# 16  Total cost :  24.190531917924982
# 17  Total cost :  24.123393290218463
# 18  Total cost :  24.066095559295384
# 19  Total cost :  24.016414784930046
# 20  Total cost :  23.972804580573982
# 21  Total cost :  23.934152719001336
# 102  Total cost :  23.476448551204857
# 103  Total cost :  23.476048407918398
# 104  Total cost :  23.475663799875445
# 105  Total cost :  23.475294110299888
# 106  Total cost :  23.4749387482574
# 107  Total cost :  23.474597147440658
# 108  Total cost :  23.474268765023837
# 109  Total cost :  23.473953080581598
# 110  Total cost :  23.473649595067663
# 111  Total cost :  23.473357829849412
# 112  Total cost :  23.47307732579418
# 113  Total cost :  23.472807642403897
# 114  Total cost :  23.472548356994803
# 115  Total cost :  23.472299063919586
# 116  Total cost :  23.472059373828795
# 117  Total cost :  23.47182891296928
# 118  Total cost :  23.471607322517542
# 119  Total cost :  23.471394257945267
# 120  Total cost :  23.471189388415812
# 121  Total cost :  23.47099239620937
# 122  Total cost :  23.4708029761752
# 123  Total cost :  23.470620835209402
# 124  Total cost :  23.470445691757078
# 125  Total cost :  23.470277275336848
# 126  Total cost :  23.47011532608735
# 127  Total cost :  23.469959594333698
# 128  Total cost :  23.46980984017354
# 129  Total cost :  23.469665833081294
# 130  Total cost :  23.469527351529546
# 131  Total cost :  23.469394182627337
# 132  Total cost :  23.469266121773448
# 133  Total cost :  23.46914297232514
# 134  Total cost :  23.46902454528069
# 135  Total cost :  23.468910658975318
# 136  Total cost :  23.46880113879012
# 137  Total cost :  23.468695816872966
# 138  Total cost :  23.468594531871258
# 139  Total cost :  23.468497128675516
# 140  Total cost :  23.46840345817374
# 141  Total cost :  23.468313377015548
# 142  Total cost :  23.468226747386442
# 143  Total cost :  23.468143436790772
# 144  Total cost :  23.468063317843797
# 145  Total cost :  23.467986268072135
# 146  Total cost :  23.467912169721995
# 147  Total cost :  23.467840909575546
# 148  Total cost :  23.467772378774185
# 149  Total cost :  23.467706472649173
# 150  Total cost :  23.467643090558926
# 151  Total cost :  23.467582135732755
# 152  Total cost :  23.46752351512071
# 153  Total cost :  23.467467139249553
# 154  Total cost :  23.467412922084332
# 155  Total cost :  23.467360780895255
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-ec9775ede022> in <module>()
# ----> 1 run()
#
# <ipython-input-9-debaed10359f> in run()
#       4     num_iterations = 1000
#       5     alpha = 0.15
# ----> 6     m = gradient_descent(x_data, y_data, num_iterations, alpha)
#       7     #return m
#       8     dataset = np.loadtxt(r"C:\Users\HP\Coding_Ninjas_ML\DataSets\test_boston_x_test.csv", delimiter=",")
#
# <ipython-input-7-4b2ba502227c> in gradient_descent(x_data, y_data, num_iterations, alpha)
#       3     for i in range(num_iterations):
#       4         m = step_gradient(m, alpha, x_data, y_data)
# ----> 5         print(i, " Total cost : ", cost(x_data, y_data, m))
#       6     return m
#
# <ipython-input-5-3ab4eec1e246> in cost(x_data, y_data, m)
#       6         for j in range(len(x_data[0])):
#       7             sum_temp += m[j] * x_data[i][j]
# ----> 8         total_cost += (1/N) * ((y_data[i] - sum_temp)**2)
#       9     return total_cost
#
# KeyboardInterrupt:
